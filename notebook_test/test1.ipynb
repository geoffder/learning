# %% [markdown]
# # This is a test notebook to see if Iike using this at all

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now I'll try to make some toy data and plot it

# %%
N = 1000
X = np.linspace(0, 6*np.pi, N) 
Y = np.sin(X) + np.random.randn(N)/5
sns.scatterplot(x=X, y=Y)

# %% [markdown]
# Cool! Now, does the fancy library actually work?

# %%
tfX = tf.placeholder(tf.float32, [None, 3]) # just testing if tensorflow works
